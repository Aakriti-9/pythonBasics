# %%
to_do_list = ["clean room", "study for exam", "write journal"]
to_do_list
# Out:
# ['clean room', 'study for exam', 'write journal']

# %%
to_do_list.append("buy groceries")
to_do_list.append("cook dinner")
to_do_list
# Out:
# ['clean room',
#  'study for exam',
#  'write journal',
#  'buy groceries',
#  'cook dinner']

# %%
to_do_list.remove("study for exam")
to_do_list
# Out:
# ['clean room', 'write journal', 'buy groceries', 'cook dinner']

# %%
if "pay bills" in to_do_list:
  print("pay bills exit in the list")
else:
    print("pay bills does not exit in the list")
# Out:
# pay bills does not exit in the list

# %%
print("Remaining tasks:")
for task in to_do_list:
    print("-", task)
# Out:
# Remaining tasks:
# - clean room
# - write journal
# - buy groceries
# - cook dinner

# %%
grades = [50, 66, 78, 45, 56, 77]
average = sum(grades) / len(grades)
print("student grades", grades)
print("average grades", average)
# Out:
# student grades [50, 66, 78, 45, 56, 77]
# average grades 62.0

# %%
inventory = ["Apples", "Bread", "Milk", "Noodles"]
inventory.append("Eggs")
inventory.append("Chips")
print("inventory")
# Out:
# inventory

# %%
inventory.remove("Milk")
print("Store Inventory")
for item in inventory:
    print("_", item)
# Out:
# Store Inventory
# _ Apples
# _ Bread
# _ Noodles
# _ Eggs
# _ Chips

# %%
numbers = [10, 20, 30, 40, 50]
third_element = numbers[2]
length = len(numbers)
is_empty = len(numbers) == 0
print("Third element:", third_element)
print("Length of the list:", length)
print("Is the list empty?", is_empty)
# Out:
# Third element: 30
# Length of the list: 5
# Is the list empty? False

# %%
sum = sum(numbers)
average = sum / len(numbers)
print("Sum of numbers:", sum)
print("Average of numbers:", average)
# Out:
# Sum of numbers: 150
# Average of numbers: 30.0

# %%
data = [45, 12, 89, 2, 67]
min_value = min(data)
max_value = max(data)
print("Minimum value:", min_value)
print("Maximum value:", max_value)
# Out:
# Minimum value: 2
# Maximum value: 89

# %%
lst = [10, 21, 4, 45, 66, 93, 11]
Even = 0
Odd = 0
for num in lst:
    if num % 2 == 0 :
        Even = Even + 1
    else:
        Odd = Odd + 1

print(" Total even numbers:", Even)
print(" Total odd numbers:", Odd)
# Out:
#  Total even numbers: 3
#  Total odd numbers: 4
